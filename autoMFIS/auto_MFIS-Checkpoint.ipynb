# %%
import numpy as np
import pandas as pd 

from fuzzyfication import Fuzzification
from tnorm import *
from formulation import Formulation
from split import Split
from reweight import Reweight
from defuzzification import Defuzzification

from sklearn.cluster import KMeans
from sklearn.linear_model import LinearRegression

from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
from math import sqrt


from basicfuzzy import trimf, trapmf

import scipy.io

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
def smape(A, F):
    return 100/len(A) * np.sum(2 * np.abs(F - A) / (np.abs(A) + np.abs(F)))
    print(len(A))

# %% [markdown]
# # Leitura de dados

# %%
'''
from datetime import datetime
# load data
def parse(x):
	return datetime.strptime(x, '%Y %m %d %H')
dataset = pd.read_csv('series/pollution.csv',  parse_dates = [['year', 'month', 'day', 'hour']], index_col=0, date_parser=parse)
dataset.drop('No', axis=1, inplace=True)
# manually specify column names
dataset.columns = ['pollution', 'dew', 'temp', 'press', 'wnd_dir', 'wnd_spd', 'snow', 'rain']
dataset.index.name = 'date'
# mark all NA values with 0
dataset['pollution'].fillna(0, inplace=True)
data = dataset.values
# integer encode direction
encoder = LabelEncoder()
data[:,4] = encoder.fit_transform(data[:,4])
'''
# Out:
# "\nfrom datetime import datetime\n# load data\ndef parse(x):\n\treturn datetime.strptime(x, '%Y %m %d %H')\ndataset = pd.read_csv('series/pollution.csv',  parse_dates = [['year', 'month', 'day', 'hour']], index_col=0, date_parser=parse)\ndataset.drop('No', axis=1, inplace=True)\n# manually specify column names\ndataset.columns = ['pollution', 'dew', 'temp', 'press', 'wnd_dir', 'wnd_spd', 'snow', 'rain']\ndataset.index.name = 'date'\n# mark all NA values with 0\ndataset['pollution'].fillna(0, inplace=True)\ndata = dataset.values\n# integer encode direction\nencoder = LabelEncoder()\ndata[:,4] = encoder.fit_transform(data[:,4])\n"

# %%
mat = scipy.io.loadmat('series/cluster1.mat')
data = mat.get('cluster1')
#data = data[:,1:]
#data = data.transpose()

# %%
#filedata = pd.read_csv("cluster1.csv", header=None)

# %%
#data = filedata.values

# %%
#data = data[:,:2]

# %%
#data.shape

# %% [markdown]
# # Definição de parâmetros

# %%
#Definicao de variaveis 

h_prev = 18
lag = 8                  #Actually, lag stands for all inputs for each serie. Example, lag = 2 uses s(t) and s(t-1) to predict s(t+1)
diff_series = True
detrend_series = True

#bin_values = 12; #Representação da binarização do tempo.
#lag_notused = []

num_series = data.shape[1]  #Numero de series do problema, extraído dos dados

max_rulesize = 4 #Max numbers of premises rules.
min_activation = 0.15 #Minimum activation

#####Definicao de funcoes######
#detrend_method = ''
#bin_method = ''

fuzzy_method = 'mfdef_cluster'
num_groups = 9
#Formacao de premissas

#form_method = 'form_NonExaustiveSparseBU_v4'
#form_param = []

# %% [markdown]
# # Pré-processamento de dados

# %%
if diff_series:
    diff_data = data[1:,:] - data[0:data.shape[0]-1,:]

    in_sample = diff_data[:diff_data.shape[0]-h_prev,:]
    
    out_sample = diff_data[diff_data.shape[0]-h_prev:,:]

elif detrend_series:
    detrended = np.zeros((data.shape))
    trends = np.zeros((data.shape))

    for i in range(data.shape[1]):
        x_detrend = [k for k in range(0, data.shape[0])]
        x_detrend = np.reshape(x_detrend, (len(x_detrend), 1))
        y = data[:,i]
        model = LinearRegression()
        model.fit(x_detrend, y)
        # calculate trend
        trend = model.predict(x_detrend)
        trends[:,i] = [trend[k1] for k1 in range(0,len(x_detrend))]
        # plot trend
        plt.plot(y)
        plt.plot(trend)
        plt.show()
        # detrend
        detrended[:,i] = [y[k2]-trend[k2] for k2 in range(0, len(x_detrend))]
        
    in_sample = detrended[:detrended.shape[0]-h_prev,:]
    out_sample = detrended[detrended.shape[0]-h_prev:,:]
    
else:
    in_sample = data[:data.shape[0]-h_prev,:]
    out_sample = data[data.shape[0]-h_prev:,:]

# %%
#Fazer detrend method

#Definicao do target
yt = np.zeros((in_sample.shape[0]-lag-1,num_series),dtype='float')

#Todas as entradas defasadas 
yp = np.zeros((in_sample.shape[0]-lag-1,num_series), dtype='float')
yp_lagged = np.zeros((in_sample.shape[0]-lag-1,num_series*lag),dtype='float')

# %%
for i in range(num_series):
    yp[:,i] = in_sample[lag:in_sample.shape[0]-1,i]
    yt[:,i] = in_sample[lag+1:,i]
    for k in range(lag):
        yp_lagged[:,i*lag+k] = in_sample[lag-k:in_sample.shape[0]-k-1,i]
        #print(i*lag+k)

# %% [markdown]
# # Apenas para visualização de dados do problema

# %% [raw]
# for n in range(yp.shape[1]):
#     plt.figure()
#     n, bins, patches = plt.hist(x=yp[:,n], bins='auto', color='#0504aa',
#                                 alpha=0.7, rwidth=0.5)
#     plt.grid(axis='y', alpha=0.75)
#     plt.xlabel('Value')
#     plt.ylabel('Frequency')

# %% [raw]
# for n in range(yp.shape[1]):
#     plt.figure()
#     plt.plot(np.linspace(0,yp.shape[0],yp.shape[0]),yp[:,n])
#     plt.grid(axis='y', alpha=0.75)
#     plt.xlabel('Time (month)')
#     plt.ylabel('Value')

# %% [raw]
# series = pd.DataFrame(yp)

# %% [raw]
# r_window_size = 10
#
# for i in range(yp.shape[1]):
#     for j in range(yp.shape[1]):
#         if (i > j) or (i == j):
#             pass
#         else:
#             plt.figure()
#
#             overall_pearson_r = series.corr().iloc[i,j]
#             rolling_r = series[i].rolling(window=r_window_size, center=True).corr(series[j])
#             f,ax=plt.subplots(2,1,figsize=(14,6),sharex=True)
#             series[i].rolling(window=3,center=True).median().plot(ax=ax[0])
#             series[j].rolling(window=3,center=True).median().plot(ax=ax[0])
#
#             ax[0].set(xlabel='Time (month)',ylabel='Values')
#             rolling_r.plot(ax=ax[1])
#             ax[1].set(xlabel='Time',ylabel='Pearson correlation')
#             plt.suptitle("Series {} and {}. Overall Pearson: {}".format(i,j,np.round(overall_pearson_r,2)))

# %% [raw]
# def crosscorr(datax, datay, lag=0, wrap=False):
#     """ Lag-N cross correlation.
#     Shifted data filled with NaNs
#
#     Parameters
#     ----------
#     lag : int, default 0
#     datax, datay : pandas.Series objects of equal length
#     Returns
#     ----------
#     crosscorr : float
#     """
#     if wrap:
#         shiftedy = datay.shift(lag)
#         shiftedy.iloc[:lag] = datay.iloc[-lag:].values
#         return datax.corr(shiftedy)
#     else:
#         return datax.corr(datay.shift(lag))
#
# for i in range(yp.shape[1]):
#     for j in range(yp.shape[1]):
#         if (i > j) or (i == j):
#             pass
#         else:
#             plt.figure()
#
#             d1 = series[i]
#             d2 = series[j]
#
#             lag_max = 5
#
#             rs = [crosscorr(d1,d2, lag) for lag in range(-lag_max,lag_max+1)]
#             offset = np.ceil(len(rs)/2)-np.argmax(rs)
#             f,ax=plt.subplots(figsize=(14,3))
#             ax.plot(np.linspace(-lag_max,lag_max,2*lag_max+1),rs)
#             ax.axvline(np.argmax(rs)-lag_max,color='r',linestyle='--',label='Peak synchrony')
#             #ax.set(title=f'Offset = {offset} frames\nS1 leads <> S2 leads',ylim=[.1,.31],xlim=[0,301], xlabel='Offset',ylabel='Pearson r')
#             ax.set(xlabel='Lag value',ylabel='Cross-correlation',title='Cross-correlation between series {} and {}'.format(i+1,j+1))
#             plt.legend()

# %% [raw]
# serie0 = np.array(series[0]).reshape(-1,1)
#
# kmeans = KMeans(n_clusters=5, random_state=0).fit(serie0)

# %% [raw]
# print(kmeans.cluster_centers_.sort)

# %% [raw]
# centers = np.asarray(kmeans.cluster_centers_)

# %% [raw]
# centers.sort(axis=0)

# %% [raw]
# [[a],[b],[c],[d],[e]] = centers.tolist()

# %% [markdown]
# # Fuzzificação dos dados

# %%
Fuzzyfy = Fuzzification(fuzzy_method)

# %%
#Lembrete: 
#axis 0 - Registros da série
#axis 1 - Valor de pertinência ao conjunto Fuzzy
#axis 2 - Numero de séries

first_time = True
for n in range(num_series):
    
    _, mf_params = Fuzzyfy.fuzzify(in_sample[:,n],np.array([]),num_groups=num_groups)
    mX, _ = Fuzzyfy.fuzzify(yp[:,n],mf_params,num_groups=num_groups)
    mY, _ = Fuzzyfy.fuzzify(yt[:,n],mf_params,num_groups=num_groups)
    if first_time:
        mX_ = np.ndarray([mX.shape[0],mX.shape[1], num_series])
        mY_ = np.ndarray([mY.shape[0],mY.shape[1], num_series])
        mf_params_ = np.ndarray([mf_params.shape[0],num_series])
        first_time = False
    mX_[:,:,n] = mX
    mY_[:,:,n] = mY
    mf_params_[:,n] = mf_params.ravel()
    #print(mf_params)
    #print(mX.shape)

# %%
a = np.array(mf_params)
a.size
# Out:
# 9

# %%
mX_lagged_ = np.ndarray([mX_.shape[0],mX_.shape[1],yp_lagged.shape[1]])
for i in range(num_series):
    mf_params = mf_params_[:,i]
    for j in range(lag):
        mX, _ = Fuzzyfy.fuzzify(yp_lagged[:,i*lag+j],mf_params,num_groups=num_groups)
        mX_lagged_[:,:,i*lag+j] = mX
        #print(i*lag+j)

# %%
#Rules are created using t-norms, like "If x1 is A and x2 is B and x3 is C"
#Each rule will be stored as a list of tuples, whose each tuple corresponds to temporal series Number and fuzzy set
#Example: if we have only one rule as "if s1 is NB", then the fuzzy rule is stored as (1,0)
#This is just for antecedent rules. If we have a complete rule "If x1 is A and x2 is B and x3 is C then x4 is Aa",
#the last tuple will be always the consequent.

# %%
mf_params
# Out:
# array([-5079.2       , -4490.        , -2531.09090909,  -361.        ,
#          522.        ,  1827.66666667,  2392.52173913,  3157.83333333,
#         5374.5       ])

# %%
Fuzzyfy.draw_fuzzy(mf_params,'a');
# Out:
# (9,)

# %%
#Here we use cardinality based on mean activation and relative frequency. We are going to use other functions to evaluate

def hybrid_func(values,min_act):
    values = np.asarray(values)
    if np.sum(values) == 0:
        return False, 0, 0
    else:
        mean_activation = np.mean(values[values>0],axis=0)
        freq = np.sum(values>0)
        freq_rel = freq/len(values)

        check_activation = mean_activation*freq_rel
        if check_activation > min_act:
            activation = True
        else:
            activation = False
        return activation, mean_activation, check_activation
    
def freq_func(values,min_act):
    values = np.asarray(values)
    if np.sum(values) == 0:
        return False, 0, 0
    else:
        freq = np.sum(values>0)
        freq_rel = freq/len(values)

        check_activation = freq_rel
        if check_activation > min_act:
            activation = True
        else:
            activation = False
        return activation, freq_rel, check_activation

def card_func(values,min_act):
    values = np.asarray(values)
    if np.sum(values) == 0:
        return False, 0, 0
    else:
        mean_activation = np.mean(values[values>0],axis=0)

        check_activation = mean_activation
        if check_activation > min_act:
            activation = True
        else:
            activation = False
        return activation, mean_activation, check_activation

# %% [markdown]
# # Formulation

# %%
form = Formulation(max_rulesize,min_activation)

# %%
rules, rulesize, prem_terms = form.run(mX_lagged_)

# %% [markdown]
# # Now, split method

# %%
#assert prem_terms.shape[1] == yt.shape[0]
from split import Split

# %%
split = Split(mY_,prem_terms,num_series)

# %%
complete_rules = split.run(rules)

# %%
# complete_rules.shape

# %%
#complete_rules[:,0]

# %% [markdown]
# # Reweighting

# %%
rw = Reweight(mY_,complete_rules,prem_terms)

# %%
wd_, agg_training = rw.run('mqr',debug=True)
# Out:
# ---------------------------
# Shape of activated prem is (2, 6)
# Shape of initial guess is (2,)
# Shape of res is (2,)
# Non-zeros weights = 1
# ---------------------------
# Shape of activated prem is (5, 11)
# Shape of initial guess is (5,)
# Shape of res is (5,)
# Non-zeros weights = 10
# ---------------------------
# Shape of activated prem is (5, 19)
# Shape of initial guess is (5,)
# Shape of res is (5,)
# Non-zeros weights = 10
# ---------------------------
# Shape of activated prem is (12, 30)
# Attempt #100
# Shape of initial guess is (12,)
# Shape of res is (12,)
# Non-zeros weights = 66
# ---------------------------
# Shape of activated prem is (35, 42)
# Attempt #100
# Attempt #200
# Attempt #300
# Shape of initial guess is (35,)
# Shape of res is (35,)
# Non-zeros weights = 577
# ---------------------------
# Shape of activated prem is (9, 41)
# Shape of initial guess is (9,)
# Shape of res is (9,)
# Non-zeros weights = 36
# ---------------------------
# Shape of activated prem is (9, 31)
# Attempt #100
# Shape of initial guess is (9,)
# Shape of res is (9,)
# Non-zeros weights = 36
# ---------------------------
# Shape of activated prem is (3, 20)
# Shape of initial guess is (3,)
# Shape of res is (3,)
# Non-zeros weights = 3
# ---------------------------
# Shape of activated prem is (2, 8)
# Shape of initial guess is (2,)
# Shape of res is (2,)
# Non-zeros weights = 1
# ---------------------------
# Shape of activated prem is (6, 12)
# Shape of initial guess is (6,)
# Shape of res is (6,)
# Non-zeros weights = 15
# ---------------------------
# Shape of activated prem is (3, 14)
# Shape of initial guess is (3,)
# Shape of res is (3,)
# Non-zeros weights = 3
# ---------------------------
# Shape of activated prem is (5, 24)
# Shape of initial guess is (5,)
# Shape of res is (5,)
# Non-zeros weights = 8
# ---------------------------
# Shape of activated prem is (23, 29)
# Attempt #100
# Shape of initial guess is (23,)
# Shape of res is (23,)
# Non-zeros weights = 253
# ---------------------------
# Shape of activated prem is (13, 30)
# Attempt #100
# Shape of initial guess is (13,)
# Shape of res is (13,)
# Non-zeros weights = 67
# ---------------------------
# Shape of activated prem is (19, 31)
# Attempt #100
# Shape of initial guess is (19,)
# Shape of res is (19,)
# Non-zeros weights = 171
# ---------------------------
# Shape of activated prem is (3, 27)
# Shape of initial guess is (3,)
# Shape of res is (3,)
# Non-zeros weights = 3
# ---------------------------
# Shape of activated prem is (7, 25)
# Shape of initial guess is (7,)
# Shape of res is (7,)
# Non-zeros weights = 21
# ---------------------------
# Shape of activated prem is (3, 13)
# Shape of initial guess is (3,)
# Shape of res is (3,)
# Non-zeros weights = 3
# ---------------------------
# Shape of activated prem is (1, 2)
# Shape of initial guess is (1,)
# Shape of res is (1,)
# Non-zeros weights = 0
# ---------------------------
# Shape of activated prem is (6, 17)
# Shape of initial guess is (6,)
# Shape of res is (6,)
# Non-zeros weights = 12
# ---------------------------
# Shape of activated prem is (13, 32)
# Attempt #100
# Shape of initial guess is (13,)
# Shape of res is (13,)
# Non-zeros weights = 78
# ---------------------------
# Shape of activated prem is (29, 50)
# Attempt #100
# Attempt #200
# Attempt #300
# Shape of initial guess is (29,)
# Shape of res is (29,)
# Non-zeros weights = 200
# ---------------------------
# Shape of activated prem is (22, 57)
# Attempt #100
# Shape of initial guess is (22,)
# Shape of res is (22,)
# Non-zeros weights = 182
# ---------------------------
# Shape of activated prem is (10, 32)
# Attempt #100
# Shape of initial guess is (10,)
# Shape of res is (10,)
# Non-zeros weights = 45
# ---------------------------
# Shape of activated prem is (1, 10)
# Shape of initial guess is (1,)
# Shape of res is (1,)
# Non-zeros weights = 0
# ---------------------------
# Shape of activated prem is (20, 21)
# Attempt #100
# Shape of initial guess is (20,)
# Shape of res is (20,)
# Non-zeros weights = 190
# ---------------------------
# Shape of activated prem is (4, 24)
# Shape of initial guess is (4,)
# Shape of res is (4,)
# Non-zeros weights = 6
# ---------------------------
# Shape of activated prem is (7, 17)
# Shape of initial guess is (7,)
# Shape of res is (7,)
# Non-zeros weights = 21
# ---------------------------
# Shape of activated prem is (6, 18)
# Shape of initial guess is (6,)
# Shape of res is (6,)
# Non-zeros weights = 15
# ---------------------------
# Shape of activated prem is (4, 22)
# Shape of initial guess is (4,)
# Shape of res is (4,)
# Non-zeros weights = 6
# ---------------------------
# Shape of activated prem is (6, 33)
# Shape of initial guess is (6,)
# Shape of res is (6,)
# Non-zeros weights = 13
# ---------------------------
# Shape of activated prem is (25, 38)
# Attempt #100
# Attempt #200
# Shape of initial guess is (25,)
# Shape of res is (25,)
# Non-zeros weights = 300
# ---------------------------
# Shape of activated prem is (5, 23)
# Shape of initial guess is (5,)
# Shape of res is (5,)
# Non-zeros weights = 10
# ---------------------------
# Shape of activated prem is (5, 8)
# Shape of initial guess is (5,)
# Shape of res is (5,)
# Non-zeros weights = 10

# %% [markdown]
# # Defuzzification

# %%
defuzz = Defuzzification(mf_params_,num_series)

# %%
y_predict_ = defuzz.run('cog',agg_training)
# Out:
# /home/medeiros/Desktop/scripts_python/defuzzification.py:54: RuntimeWarning: invalid value encountered in double_scalars
#   y_predict = sum(np.multiply(support_discourse,outResponse))/(sum(outResponse))

# %%
def mape(A,F):
    return np.mean(np.abs(np.divide(A-F,A)))

# %%
for i in range(num_series):
    idx = np.where(np.isnan(y_predict_[:,i]))

    if len(idx) > 0:
        y_predict_[idx,i] = 0
        
        print('There are {} NaN in prediction'.format(len(idx[0])))
    print('MAE score for serie {} is {}'.format(i+1,mean_absolute_error(yt[:,i], y_predict_[:,i])))
    print('RMSE for serie {} is {}'.format(i+1,sqrt(mean_squared_error(yt[:,i], y_predict_[:,i]))))
    print('SMAPE for serie {} is {}'.format(i+1,smape(yt[:,i], y_predict_[:,i])))
    print('MAPE for serie {} is {}'.format(i+1,mape(yt[:,i], y_predict_[:,i])))
    print('R2 score for serie {} is {}'.format(i+1,r2_score(yt[:,i], y_predict_[:,i])))
    print('----------------------')
# Out:
# There are 0 NaN in prediction
# MAE score for serie 1 is 125.17452271135271
# RMSE for serie 1 is 184.09417060364402
# SMAPE for serie 1 is 43.569049533545744
# MAPE for serie 1 is 0.887863289247683
# R2 score for serie 1 is 0.9169105788616514
# ----------------------
# There are 1 NaN in prediction
# MAE score for serie 2 is 199.08040917229306
# RMSE for serie 2 is 330.2581456504003
# SMAPE for serie 2 is 30.60748212618112
# MAPE for serie 2 is 0.3802214178811305
# R2 score for serie 2 is 0.9173860882394324
# ----------------------
# There are 3 NaN in prediction
# MAE score for serie 3 is 446.7363267321995
# RMSE for serie 3 is 670.7768791810983
# SMAPE for serie 3 is 95.00102983997432
# MAPE for serie 3 is 2.4892411374491354
# R2 score for serie 3 is 0.32989937803180025
# ----------------------
# There are 1 NaN in prediction
# MAE score for serie 4 is 543.1908286695922
# RMSE for serie 4 is 641.6300854475483
# SMAPE for serie 4 is 31.35330282007536
# MAPE for serie 4 is 1.3349697088276289
# R2 score for serie 4 is 0.9588026076911604
# ----------------------

# %%
fig = plt.figure(figsize=(10,6))
for i in range(num_series):
    plt.subplot(num_series,1,i+1)
    plt.title('Serie {}'.format(i+1))
    plt.plot(y_predict_[:,i],color='blue')
    plt.plot(yt[:,i],color='red')
    plt.legend(['Predicted','Target'])

# %%
if detrend_series:
    y__ = y_predict_ + trends[lag:in_sample.shape[0]-1,:]
    for i in range(num_series):

        compare_series = data[lag+1:in_sample.shape[0],i]
        plt.figure(figsize=(10,6))

        plt.title('Serie {}'.format(i+1))

        plt.plot(y__[:,i],color='blue')

        #plt.plot(data[lag:in_sample.shape[0]-1,i],color='red')

        plt.plot(compare_series, color='red')
        plt.legend(['Predicted','Target'])

        print('MAE score for serie {} is {}'.format(i+1,mean_absolute_error(compare_series, y__[:,i])))
        print('RMSE for serie {} is {}'.format(i+1,sqrt(mean_squared_error(compare_series, y__[:,i]))))
        print('SMAPE for serie {} is {}'.format(i+1,smape(compare_series, y__[:,i])))
        print('MAPE for serie {} is {}'.format(i+1,mape(compare_series, y__[:,i])))
        print('R2 score for serie {} is {}'.format(i+1,r2_score(compare_series, y__[:,i])))
        print('----------------------')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-f9777ee295a6> in <module>()
#       1 if detrend_series:
# ----> 2     y__ = y_predict_ + trends[lag:in_sample.shape[0]-1,:]
#       3     for i in range(num_series):
#       4
#       5         compare_series = data[lag+1:in_sample.shape[0],i]
#
# NameError: name 'trends' is not defined

# %%
if diff_series:
    y__ = y_predict_ + data[lag:in_sample.shape[0]-1,:]
    yt__ = yt + data[lag:in_sample.shape[0]-1,:]
    for i in range(num_series):

        compare_series = data[lag:in_sample.shape[0]-1,i]
        plt.figure(figsize=(10,6))

        plt.title('Serie {}'.format(i+1))

        plt.plot(y__[:,i],color='blue')

        plt.plot(yt__[:,i],color='red')

        plt.legend(['Predicted','Target'])

        print('MAE score for serie {} is {}'.format(i+1,mean_absolute_error(yt__[:,i], y__[:,i])))
        print('RMSE for serie {} is {}'.format(i+1,sqrt(mean_squared_error(yt__[:,i], y__[:,i]))))
        print('SMAPE for serie {} is {}'.format(i+1,smape(yt__[:,i], y__[:,i])))
        print('MAPE for serie {} is {}'.format(i+1,mape(yt__[:,i], y__[:,i])))
        print('R2 score for serie {} is {}'.format(i+1,r2_score(yt__[:,i], y__[:,i])))
        print('----------------------')

# %% [markdown]
# # Trying to remove diff from time series

# %% [raw]
# yt_without_diff = np.zeros((y_predict_.shape))
# yt_without_diff[0,:] = in_sample[lag,:] + y_predict_[0,:]
#
# for i in range(1,y_predict_.shape[0]):
#     yt_without_diff[i,:] = yt_without_diff[i-1,:] + y_predict_[i,:]

# %% [raw]
# for i in range(num_series):
#     print('RMSE for serie {} is {}'.format(i+1,sqrt(mean_squared_error(yt[:,i], yt_without_diff[:,i]))))

# %% [markdown]
# for i in range(num_series):
#     plt.figure(figsize=(10,6))
#     plt.title('Serie {}'.format(i+1))
#     plt.plot(yt_without_diff[:,i],color='blue')
#     plt.plot(in_sample[:,i],color='red')
#     plt.legend(['Predicted','Target'])

# %%
rulesize

# %% [markdown]
# # Prediction

# %%
def find_rules_by_antecedent(rules,val):
    index_ = []
    k = 0
    for rule in rules:
        #print(rule)
        if check_if_inside(val,rule[0]):
            index_.append(k)
        k += 1
    #print(index_)
    return index_

# %%
def test(rule,antecedents_activated):
    for term in rule[0]:
        
        if term in antecedents_activated:
            pass
        else:
            return False
    
    return True

# %% [markdown]
# def blabla(a,b):
#     for antec in a:
#         print(antec)
#         if not (antec in b):
#             return False
#     return True

# %%
def prem_term(rule,muX):
    prem_concat = []
    for term in rule:
        #print(term)
        prem_concat.append(muX[0,term[1],term[0]])
    return tnorm_product(prem_concat)

# %%
#Arrumação dos dados para previsão.
yp_totest = yp_lagged[yp_lagged.shape[0]-1:yp_lagged.shape[0],:]
yt_totest = np.zeros((h_prev,num_series))

# %%
for h_p in range(h_prev):
    mX_values_in = np.zeros((1,mf_params_.shape[0],yp_totest.shape[1]))
    antecedents_activated = []
    for i in range(num_series):
        mf_params = mf_params_[:,i]
        for j in range(lag):

            mX, _ = Fuzzyfy.fuzzify(np.array([yp_totest[0,i*lag+j]]),mf_params,num_groups=num_groups)
            mX_values_in[:,:,i*lag+j] = mX


            idx_nonzero = np.where(mX[0,:] > 0)
            idx_nonzero = idx_nonzero[0]

            for k in range(idx_nonzero.shape[0]):
                antecedents_activated.append((i*lag+j,idx_nonzero[k]))
            

    check_idx = 0
    rules_idx = []
    prem_terms_test = np.zeros((rules.shape[0],1))

    for n_rule in rules:
        #print('Rule {} is {}'.format(check_idx,test(n_rule,antecedents_activated)))
        if test(n_rule,antecedents_activated):
            rules_idx.append(check_idx)
        check_idx += 1
        
    prem_activated = np.zeros((rules.shape[0],))
    for i in rules_idx:
        prem_activated[i,] = prem_term(rules[i,0],mX_values_in)
    
    agg_test = np.zeros((wd_.shape))
    for i in range(num_series):
        for j in rules_idx:
            rule = complete_rules[j,i]
            consequent = rule[-1]
            agg_test[j,consequent[1],i] = prem_activated[j,]
            
            
    weight_agg = np.multiply(agg_test,wd_)
    weight_ = np.zeros((weight_agg.shape[1],weight_agg.shape[2]))

    for i in range(weight_.shape[1]):
        weight_[:,i] = weight_agg[:,:,i].max(axis=0)

    w_todefuzz = np.reshape(weight_,(1,weight_.shape[0],weight_.shape[1]))
    
    
    y_pred = defuzz.run('cog',w_todefuzz)
    
    yt_totest[h_p,:] = y_pred
    
    yp_totest = np.roll(yp_totest,1)
    
    for i in range(num_series):
        yp_totest[0,i*lag] = y_pred[0][i]

# %%
for i in range(num_series):
    print('RMSE for serie {} is {}'.format(i+1,sqrt(mean_squared_error(yt_totest[:,i], out_sample[:,i]))))
    print('SMAPE for serie {} is {}'.format(i+1,smape(out_sample[:,i],yt_totest[:,i])))
# Out:
# RMSE for serie 1 is 1288.517639659499
# SMAPE for serie 1 is 166.24330209030563
# RMSE for serie 2 is 1561.4101587535752
# SMAPE for serie 2 is 153.0015903035472
# RMSE for serie 3 is 1874.4772004976053
# SMAPE for serie 3 is 140.6915285885821
# RMSE for serie 4 is 4046.2195288210596
# SMAPE for serie 4 is 180.75752725269197

# %%
for i in range(num_series):
    plt.figure(figsize=(10,6))
    plt.title('Serie {}'.format(i+1))
    plt.plot(yt_totest[:,i],color='blue')
    plt.plot(out_sample[:,i],color='red')
    plt.legend(['Predicted','Target'])

# %% [raw]
# check_idx = 0
# rules_idx = []
# prem_terms_test = np.zeros((rules.shape[0],1))
#
# for a in rules:
#     #print('Rule {} is {}'.format(check_idx,test(a,antecedents_activated)))
#     if test(a,antecedents_activated):
#         rules_idx.append(check_idx)
#     check_idx += 1

# %% [raw]
# prem_activated = np.zeros((rules.shape[0],))
# for i in rules_idx:
#     prem_activated[i,] = prem_term(rules[i,0],mX_values_in)

# %% [raw]
# agg_test = np.zeros((wd_.shape))
# for i in range(num_series):
#     for j in rules_idx:
#         rule = complete_rules[j,i]
#         consequent = rule[-1]
#         agg_test[j,consequent[1],i] = prem_activated[j,]

# %% [markdown]
# weight_agg = np.multiply(agg_test,wd_)
# weight_ = np.zeros((weight_agg.shape[1],weight_agg.shape[2]))
#
# for i in range(weight_.shape[1]):
#     weight_[:,i] = weight_agg[:,:,i].max(axis=0)
#
# w_todefuzz = np.reshape(weight_,(1,weight_.shape[0],weight_.shape[1]))

# %% [markdown]
# y_pred = defuzz_cog(w_todefuzz,mf_params_,num_series)
# yt_totest[0,:] = y_pred

# %% [markdown]
# yt_totest[0,:] = y_pred

# %% [raw]
# yp1_totest = np.roll(yp_totest,1)

# %% [raw]
# for i in range(num_series):
#     plt.figure(figsize=(10,6))
#     plt.title('Serie {}'.format(i+1))
#     plt.plot(yt_without_diff[:,i],color='blue')
#     plt.plot(out_without_diff[:,i],color='red')
#     plt.legend(['Predicted','Target'])

# %%
if diff_series:
    Y__ = yt_totest + data[in_sample.shape[0]:data.shape[0]-1,:]
    Yt__ = out_sample + data[in_sample.shape[0]:data.shape[0]-1,:]

elif detrend_series:
    Y__ = yt_totest + trends[in_sample.shape[0]:,:]
    Yt__ = out_sample + trends[in_sample.shape[0]:,:]

else:
    Y__ = yt_totest
    Yt__ = out_sample


for i in range(num_series):
    print('Outsample RMSE for serie {} is {} \n'.format(i+1,sqrt(mean_squared_error(Yt__[:,i], Y__[:,i]))))
    print('Outsample SMAPE for serie {} is {} \n'.format(i+1,smape(Yt__[:,i],Y__[:,i])))

fig = plt.figure(figsize=(10,6))
for i in range(num_series):
    plt.subplot(num_series,1,i+1)
    plt.title('Serie {}'.format(i+1))
    plt.plot(Y__[:,i],color='blue')
    plt.plot(Yt__[:,i],color='red')
    plt.legend(['Predicted','Target'])

plt.show()
# Out:
# Outsample RMSE for serie 1 is 1288.517639659499
#
# Outsample SMAPE for serie 1 is 18.80281475339863
#
# Outsample RMSE for serie 2 is 1561.4101587535752
#
# Outsample SMAPE for serie 2 is 19.53055819446645
#
# Outsample RMSE for serie 3 is 1874.4772004976048
#
# Outsample SMAPE for serie 3 is 32.36362110324165
#
# Outsample RMSE for serie 4 is 4046.2195288210596
#
# Outsample SMAPE for serie 4 is 67.42087471952439
